# %% [markdown]
# <a href="https://colab.research.google.com/github/annvorosh/GB/blob/ML-%D0%B2-%D0%B1%D0%B8%D0%B7%D0%BD%D0%B5%D1%81%D0%B5/Weather_analytics_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install wget
import wget
import matplotlib.pyplot as plt
import pandas as pd
import gzip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
wget.download('http://93.90.217.251/download/files.synop/40/40180.08.12.2011.08.12.2021.1.0.0.ru.utf8.00000000.xls.gz')
# Out:
# 100% [..........................................................................] 2184539 / 2184539
# '40180.08.12.2011.08.12.2021.1.0.0.ru.utf8.00000000.xls.gz'

# %%
with gzip.open('40180.08.12.2011.08.12.2021.1.0.0.ru.utf8.00000000.xls.gz') as w:
    data = pd.read_excel(w)

# %%
data.head()
# Out:
#   # Метеостанция Тель-Авив / Бен-Гурион (аэропорт), Израиль, WMO_ID=40180, выборка с 08.12.2011 по 08.12.2021, все дни  \
# 0                                 # Кодировка: UTF-8
# 1  # Информация предоставлена сайтом "Расписание ...
# 2  # Пожалуйста, при использовании данных, любезн...
# 3  # Обозначения метеопараметров см. по адресу ht...
# 4                                                  #
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 0        NaN        NaN        NaN  ...         NaN         NaN         NaN
# ...

# %%
with gzip.open('40180.08.12.2011.08.12.2021.1.0.0.ru.utf8.00000000.xls.gz') as w:
    data = pd.read_excel(w, skiprows = 6)

# %%
data.head()
# Out:
#   Местное время в Тель-Авив / Бен-Гурионе (аэропорт)     T     Po      P   Pa  \
# 0                                   08.12.2021 08:00  13.8  758.5  762.2  0.8
# 1                                   08.12.2021 05:00  13.7  757.7  761.4  0.7
# 2                                   08.12.2021 02:00  15.4  757.0  760.6  0.5
# 3                                   07.12.2021 23:00  15.2  756.5  760.2  0.1
# 4                                   07.12.2021 20:00  16.6  756.4  760.0  0.9
#
#       U                                   DD   Ff  ff10  ff3  ...  \
# 0  41.0                  Ветер, дующий с юга  6.0   NaN  NaN  ...
# 1  59.0                  Ветер, дующий с юга  4.0   NaN  NaN  ...
# 2  56.0                  Ветер, дующий с юга  4.0   NaN  NaN  ...
# 3  65.0          Ветер, дующий с юго-востока  2.0   NaN  NaN  ...
# 4  71.0  Ветер, дующий с востоко-юго-востока  2.0   NaN  NaN  ...
#
#                                                   Cm  \
# ...

# %%
data.shape
# Out:
# (28533, 29)

# %%
data.columns
# Out:
# Index(['Местное время в Тель-Авив / Бен-Гурионе (аэропорт)', 'T', 'Po', 'P',
#        'Pa', 'U', 'DD', 'Ff', 'ff10', 'ff3', 'N', 'WW', 'W1', 'W2', 'Tn', 'Tx',
#        'Cl', 'Nh', 'H', 'Cm', 'Ch', 'VV', 'Td', 'RRR', 'tR', 'E', 'Tg', 'E'',
#        'sss'],
#       dtype='object')

# %%
data['Местное время в Тель-Авив / Бен-Гурионе (аэропорт)'][20]
# Out:
# '05.12.2021 20:00'

# %%
data['Местное время в Тель-Авив / Бен-Гурионе (аэропорт)']
# Out:
# 0        08.12.2021 08:00
# 1        08.12.2021 05:00
# 2        08.12.2021 02:00
# 3        07.12.2021 23:00
# 4        07.12.2021 20:00
#                ...
# 28528    08.12.2011 14:00
# 28529    08.12.2011 11:00
# 28530    08.12.2011 08:00
# 28531    08.12.2011 05:00
# 28532    08.12.2011 02:00
# Name: Местное время в Тель-Авив / Бен-Гурионе (аэропорт), Length: 28533, dtype: object

# %%
 pd.to_datetime(data['Местное время в Тель-Авив / Бен-Гурионе (аэропорт)'], dayfirst = True)
# Out:
# 0       2021-12-08 08:00:00
# 1       2021-12-08 05:00:00
# 2       2021-12-08 02:00:00
# 3       2021-12-07 23:00:00
# 4       2021-12-07 20:00:00
#                 ...
# 28528   2011-12-08 14:00:00
# 28529   2011-12-08 11:00:00
# 28530   2011-12-08 08:00:00
# 28531   2011-12-08 05:00:00
# 28532   2011-12-08 02:00:00
# Name: Местное время в Тель-Авив / Бен-Гурионе (аэропорт), Length: 28533, dtype: datetime64[ns]

# %%
data['date'] = pd.to_datetime(data['Местное время в Тель-Авив / Бен-Гурионе (аэропорт)'], dayfirst = True)

# %%
x = data['date']
y = data['T']

plt.plot(x, y)

# %%
empty_condition = data['T'].isna()
data[empty_condition]
# Out:
#       Местное время в Тель-Авив / Бен-Гурионе (аэропорт)   T     Po      P  \
# 2781                                    26.12.2020 23:00 NaN  760.2  763.9
# 4849                                    06.03.2020 14:00 NaN  754.7    NaN
# 4850                                    06.03.2020 11:00 NaN  753.7  757.6
# 8565                                    01.12.2018 17:00 NaN  760.1    NaN
# 8566                                    01.12.2018 14:00 NaN  759.5    NaN
# ...                                                  ...  ..    ...    ...
# 25892                                   24.11.2012 23:00 NaN  758.3  762.0
# 26385                                   20.09.2012 23:00 NaN  756.4  760.0
# 27082                                   17.06.2012 17:00 NaN  751.6  755.0
# 27597                                   11.04.2012 05:00 NaN  755.0  758.6
# 28154                                   25.01.2012 20:00 NaN  755.2  758.9
#
# ...

# %%
data = data[data['T'].notna()]

# %%
data[data['T'].isna()] #убрали строки без данных
# Out:
# Empty DataFrame
# Columns: [Местное время в Тель-Авив / Бен-Гурионе (аэропорт), T, Po, P, Pa, U, DD, Ff, ff10, ff3, N, WW, W1, W2, Tn, Tx, Cl, Nh, H, Cm, Ch, VV, Td, RRR, tR, E, Tg, E', sss, date]
# Index: []
#
# [0 rows x 30 columns]

# %%
plt.figure(figsize=(20, 5))
plt.plot(x, y, label = 'График температур')
plt.xlabel('Date')
plt.ylabel('Temp')
plt.legend()

# %%
data['T'].min(), data['T'].max(), data['T'].mean()
# Out:
# (0.9, 43.1, 21.5075874666295)

# %%
plt.figure(figsize = (20,8))
data['T'].hist()
# Out:
# <AxesSubplot:>

# %%
# "95-й квантиль равен 31.3 градусам" - если температура не превыает 31.3 градусов в 95% случаев
# В 90% случаев температура находится в диапазоне от <10.5> до <31.3> градусов
data['T'].quantile(0.95), data['T'].quantile(0.05)
# Out:
# (31.3, 10.5)

# %%
plt.figure(figsize = (20, 8))

condition = (data['date'] >= '2021-05-01')&(data['date'] < '2021-08-01')
data_short = data[condition]

x = data_short['date']
y = data_short['T']

plt.plot(x, y, label = 'График температур лето 2021')
plt.xlabel('Date')
plt.ylabel('Temp')
plt.legend()
plt.grid(True)

# %%
plt.figure(figsize = (20, 8))

data_summer21 = data[data['date'].between('2021-05-01', '2021-08-01')]
data_summer20 = data[data['date'].between('2020-05-01', '2020-08-01')]
data_summer19 = data[data['date'].between('2019-05-01', '2019-08-01')]

plt.plot(data_summer21['date'], data_summer21['T'], label = 'График температур лето 2021')
#plt.plot(data_summer20['date'], data_summer20['T'], label = 'График температур лето 2020', color = 'red')
#plt.plot(data_summer19['date'], data_summer19['T'], label = 'График температур лето 2019', color = 'purple')

plt.xlabel('Date')
plt.ylabel('Temp')
plt.legend()
plt.grid(True)

# %%
data_train = data[data['date'] < '2019-01-01']
data_test = data[data['date'] >= '2019-01-01']

# %%
plt.figure(figsize = (20, 8))

plt.plot(data_train['date'], data_train['T'], label = 'Тренировачный dataset', color = 'purple')
plt.plot(data_test['date'], data_test['T'], label = 'Тестовый dataset', color = 'green')

plt.xlabel('Date')
plt.ylabel('Temp')
plt.legend()
plt.grid(True)

# %%
# Создаем новый признак - день в году
data['dayofyear'] = data['date'].dt.dayofyear
# Заново переразбиваем датасет на train-test, чтобы изменения применились
data_train = data[data['date'] < '2020-01-01']
data_test = data[data['date'] >= '2020-01-01']

plt.plot(data['date'], data['dayofyear'])
plt.title('График новой фичи "день в году"')
# Out:
# Text(0.5, 1.0, 'График новой фичи "день в году"')

# %%
plt.figure(figsize = (20, 8))

plt.scatter(data['dayofyear'], data['T'], alpha=0.1)  # scatter = точки, а не линия
plt.title('Зависимость температуры от дня в году')
# Out:
# Text(0.5, 1.0, 'Зависимость температуры от дня в году')

# %%
plt.figure(figsize = (20, 8))

data_summer = data[data['dayofyear'].between(121, 214)]

plt.scatter(data_summer['dayofyear'], data_summer['T'], alpha=0.3)  # scatter = точки, а не линия
plt.title('Зависимость температуры от дня в году')
# Out:
# Text(0.5, 1.0, 'Зависимость температуры от дня в году')

# %%
from sklearn.linear_model import LinearRegression

# %%
# Для того, чтобы обучить модель, нужно разделить выборку
# на фичи (признаки, features, X) и таргет (целевую переменную, которую прогнозируем, target, y)
# 2 датасета train-test х 2 features-target - создаем 4 переменных:
# X_train, y_train, X_test, y_test

# Вначале для простототы мы будем делать прогноз только на одном факторе - номере дня в году data['dayofyear']
# Но модель ожидает, что ей на вход придет двумерная таблица -
# поэтому создаем из колонки date['T'] полноценную таблицу pandas DataFrame

X_train = pd.DataFrame()
X_train['dayofyear'] = data_train['dayofyear']
X_test = pd.DataFrame()
X_test['dayofyear'] = data_test['dayofyear']

# "y" оставляем столбцом, как есть
y_train = data_train['T']
y_test = data_test['T']

# %%
# Scatter - график из точек, а не из линий
plt.scatter(X_train['dayofyear'], y_train, alpha=0.1)  # scatter = точки, а не линия
plt.title('Зависимость температуры от дня в году')
# Out:
# Text(0.5, 1.0, 'Зависимость температуры от дня в году')

# %%
# Создаем пустой объект со случайными a и b, которые пока не описывают наши данные
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Посмотрим, какую мат. модель построила регрессия по данным, поэтому распечатаем прогноз для тренировочных данных

# Прогноз на данных, которые модель еще не видела
pred_train = model.predict(X_train)
pred_test = model.predict(X_test)

# %%
# Проверяем качество численно

# mean_squared_error - средняя сумма квадратов отклонений (меньше -> лучше)

from sklearn.metrics import mean_squared_error

mean_squared_error(y_train, pred_train), mean_squared_error(y_test, pred_test) # Чем число меньше - тем лучше
# Out:
# (39.60279831554404, 34.07729891314421)

# %%
# Собираем все воедино
# 1) LinearRegression + dayofyear
data['dayofyear'] = data['date'].dt.dayofyear
# Заново переразбиваем датасет на train-test, чтобы изменения применились
data_train = data[data['date'] < '2019-01-01']
data_test = data[data['date'] >= '2019-01-01']

X_train = pd.DataFrame()
X_train['dayofyear'] = data_train['dayofyear']
X_test = pd.DataFrame()
X_test['dayofyear'] = data_test['dayofyear']

y_train = data_train['T']
y_test = data_test['T']

model = LinearRegression()
model.fit(X_train, y_train)

pred_train = model.predict(X_train)
pred_test = model.predict(X_test)

plt.figure(figsize=(20, 5))
plt.plot(data_train['date'], y_train)
plt.plot(data_train['date'], pred_train)
plt.plot(data_test['date'], y_test)
plt.plot(data_test['date'], pred_test)

print('Ошибка модели на обучающих данных', mean_squared_error(y_train, pred_train))
print('Ошибка модели на тестовых данных', mean_squared_error(y_test, pred_test))
# Out:
# Ошибка модели на обучающих данных 39.64013495221412
# Ошибка модели на тестовых данных 36.20270294245885

# %%
import numpy as np

# %%
# Посмотрим, в каком диапазоне находятся данные признака dayofyear
data['dayofyear'].min(), data['dayofyear'].max()
# Out:
# (1, 366)

# %%
# Перешли к интервалу от 0 до 2pi
# [1, 366] -> [0, 1) -> [0, 2pi)
new_interval = ((data['dayofyear'] - 1) / (365+1)) * 2 * np.pi

new_interval.min(), new_interval.max(), 2 * np.pi
# Out:
# (0.0, 6.26601813420915, 6.283185307179586)

# %%
# Вернемся на шаг 1 feature generation - создаем новые признаки:
# scaled_dayofyear - сжимает диапазон [1, 366] -> [0, 2pi] - переходим в радианы
# cos_dayofyear - косинус дня в году (= длина проекции номера дня в году на горизонтальную ось, если нпредставить номера циферблатом)

data['cos_dayofyear'] = np.cos(((data['dayofyear'] - 1) / (365+1)) * 2 * np.pi)

# %%
# График исходных данных
plt.plot(data['date'], data['dayofyear'])

# %%
plt.plot(data['date'], data['cos_dayofyear'])

# %%
#  LinearRegression + cos dayofyear
# Linear Regression на тригонометрических параметрах
# z=acos((x−1)/366∗2π)+b

# Переходим в радианы, создаем новую переменную с cos
data['cos_dayofyear'] = np.cos(((data['dayofyear'] - 1) / (365+1)) * 2 * np.pi)

# Повторяем все то же самое
data_train = data[data['date'] < '2020-01-01']
data_test = data[data['date'] >= '2020-01-01']

X_train = pd.DataFrame()
X_train['dayofyear'] = data_train['cos_dayofyear']  # <- новый признак
X_test = pd.DataFrame()
X_test['dayofyear'] = data_test['cos_dayofyear']  # <- новый признак

y_train = data_train['T']
y_test = data_test['T']

model = LinearRegression()
model.fit(X_train, y_train)

pred_train = model.predict(X_train)
pred_test = model.predict(X_test)

plt.figure(figsize=(20, 5))
plt.plot(data_train['date'], y_train)
plt.plot(data_train['date'], pred_train)
plt.plot(data_test['date'], y_test)
plt.plot(data_test['date'], pred_test)

print('Ошибка модели на обучающих данных', mean_squared_error(y_train, pred_train))
print('Ошибка модели на тестовых данных', mean_squared_error(y_test, pred_test))
# Out:
# Ошибка модели на обучающих данных 21.216804882929797
# Ошибка модели на тестовых данных 23.868319676013325

# %%
# 3) Decision Tree + dayofyear
from sklearn.tree import DecisionTreeRegressor
# Повторяем все то же самое
data_train = data[data['date'] < '2020-01-01']
data_test = data[data['date'] >= '2020-01-01']

X_train = pd.DataFrame()
X_train['dayofyear'] = data_train['dayofyear']  # <- старый признак
X_test = pd.DataFrame()
X_test['dayofyear'] = data_test['dayofyear']  # <- старый признак

y_train = data_train['T']
y_test = data_test['T']

model = DecisionTreeRegressor()  # <- новая модель
model.fit(X_train, y_train)

pred_train = model.predict(X_train)
pred_test = model.predict(X_test)

plt.figure(figsize=(20, 5))
plt.plot(data_train['date'], y_train)
plt.plot(data_train['date'], pred_train)
plt.plot(data_test['date'], y_test)
plt.plot(data_test['date'], pred_test)

# Ошибка ЛинРег на cos на обучающих данных 21.216804882929797
# Ошибка ЛинРег на cos на тестовых данных 23.868319676013325
print('Ошибка модели на обучающих данных', mean_squared_error(y_train, pred_train))
print('Ошибка модели на тестовых данных', mean_squared_error(y_test, pred_test))
# Out:
# Ошибка модели на обучающих данных 13.95145003153227
# Ошибка модели на тестовых данных 15.010727174913441

# %%
# Исправляем переобучение - задаем модели ограничения, чтобы она стала проще и не смогла зубрить
# В случае дерева мы можем играть с глубиной max_depth / количеством листьев

data_train = data[data['date'] < '2021-05-01']
data_test = data[data['date'] >= '2021-05-01']

X_train = pd.DataFrame()
X_train['dayofyear'] = data_train['dayofyear']  # <- старый признак
X_test = pd.DataFrame()
X_test['dayofyear'] = data_test['dayofyear']  # <- старый признак

y_train = data_train['T']
y_test = data_test['T']

model = DecisionTreeRegressor(max_depth = 5)  # <- новая модель
model.fit(X_train, y_train)

pred_train = model.predict(X_train)
pred_test = model.predict(X_test)

plt.figure(figsize=(20, 5))
plt.plot(data_train['date'], y_train)
plt.plot(data_train['date'], pred_train)
plt.plot(data_test['date'], y_test)
plt.plot(data_test['date'], pred_test)

# Ошибка ЛинРег на cos на обучающих данных 21.216804882929797
# Ошибка ЛинРег на cos на тестовых данных 23.868319676013325
print('Ошибка модели на обучающих данных', mean_squared_error(y_train, pred_train))
print('Ошибка модели на тестовых данных', mean_squared_error(y_test, pred_test))
# Out:
# Ошибка модели на обучающих данных 14.579379961846685
# Ошибка модели на тестовых данных 12.350076560425553

# %%
data['dayofyear'] = data['date'].dt.dayofyear

data_test = data[data['date'] >= '2021-05-01']
plt.figure(figsize = (20, 8))
#plt.plot(data_test['date'], y_test)
plt.plot(data_test['date'], pred_test)
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Temp, ℃')
plt.title('Ожидаемая температура на предстоящий год', color = 'red')
print(f'Ожидаемые отклонения могут составить {int(np.sqrt(mean_squared_error(y_test, pred_test)))} -  {int(np.sqrt(mean_squared_error(y_train, pred_train)))} градусa')
# Out:
# Ожидаемые отклонения могут составить 3 -  3 градусa
