# %% [markdown]
# <a href="https://colab.research.google.com/github/annvorosh/GB/blob/DAmed/DAmed_L03_medicines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Урок 3. Data Science: разработке и тестировании лекарств
# ##### В онлайн-инструментах (и не только) используются данные о химических веществах в формате SMILES. Обычно он используется для описания структуры химических молекул. SMILES - это аббревиатура от Simplified Molecular Input Line Entry Specification.
# ##### Все основные данные о веществах можно найти в базе данных PubChem. PubChem в основном содержит небольшие молекулы, но также и более крупные молекулы, такие как нуклеотиды, углеводы, липиды, пептиды и химически модифицированные макромолекулы. Также есть информация о химических структурах, идентификаторах, химических и физических свойствах, биологической активности, патентах, данных о здоровье, безопасности, токсичности и многом другом.
# #### Некоторые инструменты для предсказания мишеней:
# - SwissTargetPrediction - позволяет оценить наиболее вероятные макромолекулярные мишени небольшой молекулы, предполагаемой как биологически активная. Предсказание основано на сочетании двухмерного и трехмерного сходства с библиотекой из 370 000 известных активных веществ для более чем 3000 белков трех разных видов.
# - Super-PRED - веб-сервер прогнозирования соединений, основанный на модели машинного обучения с использованием логистической регрессии.
# - Tools4miRs - представляет собой веб-мета-сервер прогнозирования целей, включающий определяемые пользователем методы прогнозирования целей при анализе предоставленных пользователями данных.
#
# ● Найдите в интернете лекарство, вышедшее из употребления, сделайте поиск его структуры по химическим базам данных. Затем с помощью одного из описанных выше тулов предскажите мишени для этого лекарства. Изучите найденные мишени и предположите, какие заболевания может лечить данное лекарство при взаимодействии с предсказанными мишенями.

# %% [markdown]
# https://pubchem.ncbi.nlm.nih.gov/#query=Vioxx

# %% [markdown]
# **Vioxx (рофекоксиб)** был прекращен из-за риска сердечно-сосудистых осложнений. Структура рофекоксиба может быть найдена в базах данных химических соединений, таких как PubChem или ChEMBL, используя его идентификатор или название.
#
# Это структурная формула рофекоксиба:
#
# Rofecoxib Structure
#
# Формула: C17H14O4S
#
# IUPAC название: 3-(4-метилсульфонилфенил)-4-фенил-2H-фуран-5-он
#
# SMILES: CS(=O)(=O)C1=CC=C(C=C1)C2=C(C(=O)OC2)C3=CC=CC=C3
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Теперь можно воспользоваться одним из инструментов, таким как SwissTargetPrediction или Super-PRED, чтобы предсказать мишени для этого лекарства, используя структурную формулу рофекоксиба (C17H14O4S) или его SMILES (CS(=O)(=O)C1=CC=C(C=C1)C2=C(C(=O)OC2)C3=CC=CC=C3) для поиска мишеней в этих базах данных.
#
# http://www.swisstargetprediction.ch/result.php?job=1038449412&organism=Homo_sapiens

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Вот некоторые из мишеней в списке, которые могут быть связаны с определенными заболеваниями или патологиями:
#
# - Cyclooxygenase Циклооксигеназы (**COX-1 и COX-2**): Ингибиторы COX могут использоваться для лечения воспалительных заболеваний и боли.
#
# - Cytochrome P450 (**CYP17A1, CYP11B1, CYP11B2**): Эти ферменты могут быть связаны с обменом гормонов и заболеваниями, такими как гормональные нарушения.
#
# - Метаботропный глутаматный рецептор 5 (**GRM5**): Связан с нейротрансмиссией и может быть связан с психическими расстройствами.
#
# - Фосфодиэстераза 10A (**PDE10A**): Имеет значение в центральной нервной системе и может быть связана с психическими расстройствами.
#
# - Допаминовый рецептор D1 (**DRD1**): Связан с допамином и может быть связан с некоторыми психическими расстройствами.
#
# - Тирозинкиназы (**Kinases**): Широкий класс ферментов, который может быть связан с различными видами рака или другими патологиями.
#
# - Thymidylate synthase (**TYMS**): Может быть связан с раковыми заболеваниями.
#
# - Hormone sensitive lipase (**LIPE**): Может быть связана с метаболическими расстройствами.
#
# - Ацетилхолинэстераза (**ACHE**): Связана с нейрологическими расстройствами, такими как болезнь Альцгеймера.
#
# - Nitric oxide synthase (**NOS2, NOS1**): Играют роль в регуляции сосудистого тонуса и иммунной системы.
#
# - Прогестероновый рецептор (**PGR**): Может быть связан с репродуктивными заболеваниями.
#
# - Cathepsin (CTSB, CTSL, CTSK): Могут быть связаны с дегенеративными заболеваниями.
