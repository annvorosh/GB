# %% [markdown]
# <a href="https://colab.research.google.com/github/annvorosh/GB/blob/DAmed/DAmed_L04_clinicaltrials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Введение в анализ данных в медицине
# ## Урок 4. Клинические исследования
# Найти на сайте clinicaltrials.gov с помощью расширенного поиска interventional исследование, лучше 3 фазы, у которого будет доступен план статистического анализа (SAP) или протокол и результаты.
# 1. Посмотреть как устроен документ
# 2. Найти описание дизайна исследования - рандомизированное или нет, какое заслепление, какое показание, какие группы сравнения, сколько человек в каждой группе сравнения, есть ли стратификация и по каким признакам
# 3. Найти раздел с конечными точками, разобрать каждую точку и определить ее тип - первичная/вторичная, клиническая/суррогатная
# 4. Посмотреть результаты на сайте на странице исследования, определить было исследование успешным или нет.

# %% [markdown]
# https://clinicaltrials.gov/study/NCT05325853?aggFilters=docs:sap,phase:3%202%201%200,results:with&page=3&rank=25
#
# ***Исследование безопасности и местного анестезирующего действия офтальмологического раствора AG-920 в детской популяции***
# - Идентификатор ClinicalTrials.gov **NCT05325853**
# - Спонсор Американская Геномика, ООО
# - Информация предоставлена American Genomics, LLC (Ответственная сторона)
# - Последнее опубликованное обновление 2023-10-25

# %% [markdown]
# 1.
# На сайте clinicaltrials.gov каждое исследование имеет свою собственную страницу с деталями исследования, включая:

# %% [markdown]
# **Это клиническое исследование, исследующее применение стерильного топического офтальмологического раствора артикаина (AG-920) по сравнению с 0,5% гидрохлоридом пропаракаина у детей, проходящих обследование глаза. Вот подробности исследования:**
#
# **Дизайн исследования:**
#
# - Рандомизация: Участники были случайным образом распределены между группами AG-920 и Пропаракаина.
# - Модель вмешательства: Параллельное назначение.
# - Заслепление: Одиночное (участник), что означает, что участники и их опекуны не знали о присвоенном лечении.
# - Основная цель: Поддерживающая терапия.
# - Информация о стратификации участников в этом конкретном исследовании не предоставляется в тексте. Стратификация обычно подразумевает разделение участников на группы с целью более равномерного распределения факторов, которые могут повлиять на результаты исследования. Эти группы могут быть созданы на основе различных признаков, таких как возраст, пол, медицинская история, степень тяжести заболевания и т. д. Однако из предоставленной информации не видно явной стратификации участников по каким-либо конкретным признакам.
#
# ***Детали участников:***
# - Регистрация: 61 детский участник.
# - Исходные характеристики: Обе группы лечения включали по 30 участников.
# - Возраст: Участники были в возрасте до 18 лет.
# - Пол: Почти равное количество мужчин и женщин.
# - Этническая принадлежность и раса: Преимущественно испаноговорящие/латиноамериканские и белые участники.
# - Регион участия: Соединенные Штаты.

# %% [markdown]
# **Конечные точки,** описанные в записи исследования, включают:
#
# *   ПЕРВИЧНАЯ: Доля участников, у которых удалось провести обследование глаза успешно: оценивает возможность проведения обследования глаз без дополнительной анестезии.
# *   ВТОРИЧНАЯ: Число участников с нежелательными событиями, возникшими в процессе лечения (TEAEs): оценивает возможные нежелательные события, которые могут быть связаны с применением растворов AG-920 и Пропаракаина в офтальмологических целях.
#
# В обоих случаях, обсуждаемые конечные точки являются клиническими, так как они прямо связаны с клиническими результатами или нежелательными событиями, влияющими на пациентов в процессе лечения в реальной клинической практике.
# Исходя из предоставленных данных, обе конечные точки, кажется, были достигнуты успешно для обеих групп лечения.

# %% [markdown]
# **Результаты исследования:**
# - Доля участников, у которых удалось провести обследование глаза успешно: 100% успешности в обеих группах.
# - Нежелательные события, возникшие во время лечения (TEAEs): о событиях не сообщалось в обеих группах.
#
# **ВЫВОД: исследование было успешным**
