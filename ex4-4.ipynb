# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

a = np.linspace(0.01, 0.02, 100)
x = np.linspace(100, 500, 100)
x = np.pi / a
plt.plot(x, a, 'purple')
plt.xlabel('Ось Х')
plt.ylabel('Ось a')
plt.grid(True)
plt.show()
