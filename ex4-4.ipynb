# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

a = np.linspace(0.005, 0.025, 100)
x = np.linspace(0, 500, 100)

for n in range (1,5):
    x = np.pi * n / a
    plt.plot(x, a, 'purple')

plt.xlabel('Ось Х')
plt.ylabel('Ось a')
plt.grid(True)
plt.show()
